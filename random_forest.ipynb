# %%
# import deep learning libraries
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.utils import resample
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, classification_report
import glob
from tqdm import tqdm
from pathlib import Path
import pickle

# %%
SEED = 1706

# %%
numpy_file_path = 'data/processed/concatenated_features.npy'

if Path.exists(Path(numpy_file_path)):
    print('Loading numpy file...')
    data = np.load(numpy_file_path)
else:
    path = 'data/processed/pd_feature_array'
    all_files = glob.glob(path + "/*.parquet")

    df_li = []
    fail = []

    def check_shape(frame, filename):
        arr = np.array(frame)
        arr = arr.reshape(-1, 5596)
        target = arr[:, -1]
        set_target = set(target)
        for i in set_target:
            assert i in [0, 1], "Error in {}".format(filename)

    for filename in tqdm(all_files):
        frame = pd.read_parquet(filename)
        check_shape(frame, filename)
        df_li.append(frame)

    print("Concatenating dataframes")
    df = pd.concat(df_li)

    print("Deleting df_li")
    del(df_li)

    print(f'Filling {df[df.isnull().any(1)].size} NaNs')
    df.fillna(0, inplace=True)
    data = np.array(df).reshape(-1, 5596)
    np.save(numpy_file_path, )
# Out:
# Loading numpy file...

# %%
print("Delete df after getting array")
try:
    del(df)
except:
    pass
# Out:
# Delete df after getting array

# %%
# split into training and test set
x_train, x_test, y_train, y_test = train_test_split(data[:, :-1], data[:, -1], test_size=0.2, random_state=SEED, shuffle=True)

# upsample minority class
x_minority = x_train[y_train == 0]
y_minority = y_train[y_train == 0]
x_majority = x_train[y_train == 1]
y_majority = y_train[y_train == 1]

x_majority_subsample, y_majority_subsample = resample(x_majority, y_majority, replace=False, n_samples=x_minority.shape[0], random_state=SEED)

x_train_balanced = np.concatenate((x_majority_subsample, x_minority))
y_train_balanced = np.concatenate((y_majority_subsample, y_minority))

# %%
model_search = RandomForestClassifier(random_state=SEED)
param_grid = {'n_estimators': [100, 200, 500, 1000],
              'max_depth': [6, 8, 10, 12, 14],
              'max_features': ['auto', 'sqrt', 'log2'],
              'criterion': ['gini', 'entropy']}

CV_model = GridSearchCV(estimator=model_search, param_grid=param_grid, cv=5, n_jobs=-1, verbose=100)
CV_model.fit(x_train_balanced, y_train_balanced)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV 3/5; 2/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=200
# [CV 3/5; 3/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=500
# [CV 2/5; 10/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=200
# [CV 5/5; 4/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=1000
# [CV 3/5; 15/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=500
# [CV 5/5; 35/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=500
# [CV 3/5; 4/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=1000
# [CV 1/5; 10/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=200
# [CV 1/5; 11/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=500
# [CV 2/5; 18/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200
# [CV 4/5; 1/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=100
# [CV 4/5; 12/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=1000
# [CV 5/5; 1/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=100
# [CV 3/5; 5/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=100
# [CV 5/5; 8/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=1000
# [CV 2/5; 12/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=1000
# [CV 2/5; 7/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=500
# [CV 3/5; 32/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1000
# [CV 5/5; 3/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=500
# [CV 4/5; 11/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=500
# [CV 3/5; 9/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=100
# [CV 3/5; 10/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=200
# [CV 5/5; 5/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=100
# [CV 1/5; 16/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=1000
# [CV 1/5; 6/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=200
# [CV 1/5; 14/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=200
# [CV 1/5; 12/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=1000
# [CV 1/5; 27/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=500
# [CV 4/5; 3/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=500
# [CV 4/5; 6/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=200
# [CV 1/5; 9/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=100
# [CV 3/5; 1/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=100
# [CV 1/5; 19/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500
# [CV 1/5; 22/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=200
# [CV 2/5; 1/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=100
# [CV 1/5; 4/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=1000
# [CV 3/5; 16/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=1000
# [CV 1/5; 2/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=200
# [CV 1/5; 37/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=100
# [CV 3/5; 17/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=100
# [CV 3/5; 23/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=500
# [CV 2/5; 8/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=1000
# [CV 4/5; 22/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=200
# [CV 5/5; 11/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=500
# [CV 3/5; 22/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=200
# [CV 3/5; 8/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=1000
# [CV 5/5; 2/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=200
# [CV 2/5; 13/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=100
# [CV 1/5; 8/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=1000
# [CV 4/5; 13/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=100
# [CV 4/5; 17/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=100
# [CV 2/5; 9/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=100
# [CV 2/5; 26/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=200
# [CV 4/5; 8/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=1000
# [CV 1/5; 15/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=500
# [CV 1/5; 24/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=1000
# [CV 3/5; 36/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=1000
# [CV 5/5; 26/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=200
# [CV 4/5; 7/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=500
# [CV 1/5; 34/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=200
# [CV 3/5; 20/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=1000
# [CV 5/5; 20/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=1000
# [CV 1/5; 7/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=500
# [CV 4/5; 15/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=500
# [CV 5/5; 16/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=1000
# [CV 3/5; 14/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=200
# [CV 1/5; 5/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=100
# [CV 2/5; 29/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100
# [CV 3/5; 7/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=500
# [CV 2/5; 3/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=500
# [CV 5/5; 13/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=100
# [CV 5/5; 10/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=200
# [CV 4/5; 30/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200[CV 1/5; 3/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=500
#
# [CV 4/5; 33/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=100
# [CV 5/5; 12/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=1000
# [CV 2/5; 22/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=200
# [CV 2/5; 4/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=1000
# [CV 1/5; 33/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=100
# [CV 3/5; 6/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=200
# [CV 2/5; 20/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=1000
# [CV 2/5; 30/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 31/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500
# [CV 3/5; 29/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100
# [CV 4/5; 26/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=200
# [CV 5/5; 7/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=500
# [CV 2/5; 34/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=200
# [CV 2/5; 21/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=100
# [CV 4/5; 9/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=100
# [CV 2/5; 2/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=200
# [CV 4/5; 23/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=500
# [CV 2/5; 17/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=100
# [CV 3/5; 24/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=1000
# [CV 1/5; 39/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=500
# [CV 4/5; 27/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=500
# [CV 3/5; 12/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=1000
# [CV 1/5; 43/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=500
# [CV 5/5; 28/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=1000
# [CV 4/5; 18/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200
# [CV 2/5; 36/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=1000
# [CV 4/5; 32/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1000
# [CV 2/5; 16/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=1000
# [CV 1/5; 13/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=100
# [CV 5/5; 6/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=200
# [CV 4/5; 4/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=1000
# [CV 5/5; 17/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=100
# [CV 5/5; 18/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200
# [CV 3/5; 31/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500
# [CV 1/5; 28/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=1000[CV 5/5; 22/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=200
# [CV 3/5; 18/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200
#
# [CV 4/5; 42/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=200
# [CV 4/5; 36/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=1000
# [CV 4/5; 5/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=100
# [CV 3/5; 19/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500
# [CV 2/5; 33/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=100
# [CV 4/5; 10/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=200
# [CV 2/5; 41/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100
# [CV 3/5; 37/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=100
# [CV 1/5; 1/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=100
# [CV 3/5; 25/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=100
# [CV 4/5; 29/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100
# [CV 3/5; 28/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=1000
# [CV 2/5; 5/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=100
# [CV 3/5; 33/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=100
# [CV 4/5; 2/120] START criterion=gini, max_depth=6, max_features=auto, n_estimators=200
# [CV 5/5; 9/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=100
# [CV 3/5; 13/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=100
# [CV 2/5; 14/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=200
# [CV 1/5; 26/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=200
# [CV 2/5; 11/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=500
# [CV 1/5; 32/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1000
# [CV 5/5; 23/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=500
# [CV 1/5; 38/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=200
# [CV 5/5; 32/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1000
# [CV 5/5; 38/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=200
# [CV 2/5; 19/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500
# [CV 5/5; 19/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500
# [CV 5/5; 24/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=1000
# [CV 2/5; 28/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=1000
# [CV 4/5; 20/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=1000
# [CV 3/5; 38/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=200
# [CV 5/5; 34/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=200
# [CV 2/5; 35/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=500
# [CV 4/5; 41/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100
# [CV 5/5; 29/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100
# [CV 1/5; 35/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=500
# [CV 4/5; 16/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=1000
# [CV 4/5; 14/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=200
# [CV 5/5; 30/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 30/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 21/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=100
# [CV 4/5; 40/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=1000
# [CV 3/5; 40/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=1000
# [CV 2/5; 39/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=500
# [CV 4/5; 28/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=1000
# [CV 1/5; 21/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=100
# [CV 1/5; 18/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=200
# [CV 1/5; 17/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=100
# [CV 4/5; 19/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=500
# [CV 2/5; 6/120] START criterion=gini, max_depth=6, max_features=sqrt, n_estimators=200
# [CV 5/5; 21/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=100
# [CV 2/5; 23/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=500
# [CV 1/5; 25/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=100
# [CV 5/5; 27/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=500
# [CV 4/5; 21/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=100
# [CV 5/5; 33/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=100
# [CV 3/5; 42/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=200
# [CV 2/5; 27/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=500
# [CV 5/5; 31/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500
# [CV 4/5; 24/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=1000
# [CV 5/5; 14/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=200
# [CV 1/5; 20/120] START criterion=gini, max_depth=8, max_features=sqrt, n_estimators=1000
# [CV 2/5; 32/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1000
# [CV 2/5; 31/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500
# [CV 3/5; 35/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=500
# [CV 4/5; 35/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=500
# [CV 3/5; 11/120] START criterion=gini, max_depth=6, max_features=log2, n_estimators=500
# [CV 3/5; 39/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=500
# [CV 5/5; 37/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=100
# [CV 5/5; 36/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=1000
# [CV 1/5; 40/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=1000
# [CV 5/5; 25/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=100
# [CV 2/5; 24/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=1000
# [CV 5/5; 15/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=500
# [CV 4/5; 31/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=500
# [CV 1/5; 36/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=1000
# [CV 1/5; 29/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100
# [CV 2/5; 25/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=100
# [CV 5/5; 40/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=1000
# [CV 1/5; 23/120] START criterion=gini, max_depth=8, max_features=log2, n_estimators=500
# [CV 4/5; 39/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=500
# [CV 5/5; 41/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100
# [CV 2/5; 42/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=200
# [CV 1/5; 41/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100
# [CV 2/5; 15/120] START criterion=gini, max_depth=8, max_features=auto, n_estimators=500
# [CV 3/5; 43/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=500
# [CV 3/5; 34/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=200
# [CV 4/5; 25/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=100
# [CV 3/5; 26/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=200
# [CV 5/5; 39/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=500
# [CV 4/5; 37/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=100
# [CV 2/5; 37/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=100
# [CV 1/5; 42/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=200
# [CV 3/5; 27/120] START criterion=gini, max_depth=10, max_features=auto, n_estimators=500
# [CV 3/5; 41/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100
# [CV 4/5; 38/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=200
# [CV 3/5; 30/120] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 43/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=500
# [CV 2/5; 38/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=200
# [CV 4/5; 34/120] START criterion=gini, max_depth=10, max_features=log2, n_estimators=200
# [CV 4/5; 43/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=500
# [CV 2/5; 44/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=1000
# [CV 2/5; 40/120] START criterion=gini, max_depth=12, max_features=auto, n_estimators=1000
# [CV 1/5; 44/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=1000
# [CV 3/5; 44/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=1000
# [CV 5/5; 42/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=200
# [CV 5/5; 43/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=500
# [CV 5/5; 45/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=100
# [CV 3/5; 45/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=100
# [CV 1/5; 45/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=100
# [CV 5/5; 44/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=1000
# [CV 4/5; 45/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=100
# [CV 4/5; 46/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=200
# [CV 4/5; 44/120] START criterion=gini, max_depth=12, max_features=sqrt, n_estimators=1000
# [CV 2/5; 45/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=100
# [CV 2/5; 51/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=500
# [CV 5/5; 47/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=500
# [CV 1/5; 52/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=1000
# [CV 2/5; 50/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=200
# [CV 2/5; 48/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=1000
# [CV 5/5; 48/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=1000
# [CV 4/5; 47/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=500
# [CV 2/5; 47/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=500
# [CV 4/5; 48/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=1000
# [CV 3/5; 51/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=500
# [CV 4/5; 51/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=500
# [CV 5/5; 49/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=100
# [CV 2/5; 46/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=200
# [CV 3/5; 50/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=200
# [CV 3/5; 47/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=500
# [CV 4/5; 49/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=100
# [CV 4/5; 50/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=200
# [CV 1/5; 46/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=200
# [CV 2/5; 49/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=100
# [CV 1/5; 50/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=200
# [CV 1/5; 48/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=1000
# [CV 1/5; 49/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=100
# [CV 3/5; 48/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=1000
# [CV 1/5; 47/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=500
# [CV 1/5; 51/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=500
# [CV 5/5; 46/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=200
# [CV 3/5; 49/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=100
# [CV 5/5; 51/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=500
# [CV 3/5; 46/120] START criterion=gini, max_depth=12, max_features=log2, n_estimators=200
# [CV 5/5; 50/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=200
# [CV 3/5; 9/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=100;, score=0.878 total time=  12.4s
# [CV 1/5; 9/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=100;, score=0.882 total time=  12.2s
# [CV 2/5; 52/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=1000
# [CV 3/5; 52/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=1000
# [CV 4/5; 9/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=100;, score=0.893 total time=  12.0s
# [CV 4/5; 52/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=1000
# [CV 5/5; 9/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=100;, score=0.895 total time=  13.2s
# [CV 5/5; 52/120] START criterion=gini, max_depth=14, max_features=auto, n_estimators=1000
# [CV 2/5; 10/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=200;, score=0.905 total time=  16.5s
# [CV 1/5; 53/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=100
# [CV 5/5; 45/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=100;, score=0.955 total time=  10.3s
# [CV 2/5; 53/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=100
# [CV 2/5; 9/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=100;, score=0.901 total time=  17.5s
# [CV 3/5; 53/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=100
# [CV 4/5; 33/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.941 total time=  17.4s
# [CV 3/5; 21/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=100;, score=0.920 total time=  15.5s
# [CV 4/5; 53/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=100
# [CV 5/5; 53/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=100
# [CV 3/5; 33/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.943 total time=  17.8s
# [CV 1/5; 54/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=200
# [CV 1/5; 33/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.939 total time=  21.2s
# [CV 2/5; 33/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.948 total time=  20.2s
# [CV 2/5; 54/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=200
# [CV 3/5; 54/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=200
# [CV 2/5; 45/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=100;, score=0.958 total time=  15.5s
# [CV 4/5; 54/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=200
# [CV 5/5; 21/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=100;, score=0.926 total time=  20.7s
# [CV 3/5; 10/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=200;, score=0.884 total time=  23.9s
# [CV 5/5; 54/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=200
# [CV 1/5; 55/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=500
# [CV 3/5; 45/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=100;, score=0.957 total time=  17.5s
# [CV 2/5; 55/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=500
# [CV 4/5; 45/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=100;, score=0.956 total time=  17.5s
# [CV 3/5; 55/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=500
# [CV 4/5; 22/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=200;, score=0.922 total time=  25.0s
# [CV 4/5; 55/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=500
# [CV 5/5; 10/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=200;, score=0.893 total time=  25.1s
# [CV 2/5; 21/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=100;, score=0.931 total time=  24.3s
# [CV 5/5; 55/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=500
# [CV 1/5; 56/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=1000
# [CV 5/5; 22/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=200;, score=0.927 total time=  24.1s
# [CV 2/5; 56/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=1000
# [CV 3/5; 22/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=200;, score=0.916 total time=  31.8s
# [CV 3/5; 56/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=1000
# [CV 5/5; 34/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200;, score=0.947 total time=  30.1s
# [CV 4/5; 56/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=1000
# [CV 1/5; 21/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=100;, score=0.914 total time=  30.4s
# [CV 5/5; 56/120] START criterion=gini, max_depth=14, max_features=sqrt, n_estimators=1000
# [CV 5/5; 33/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=100;, score=0.948 total time=  30.2s
# [CV 1/5; 11/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=500;, score=0.883 total time=  34.1s
# [CV 1/5; 57/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=100
# [CV 2/5; 57/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=100
# [CV 4/5; 21/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=100;, score=0.926 total time=  31.5s
# [CV 3/5; 57/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=100
# [CV 1/5; 46/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=200;, score=0.953 total time=  27.6s
# [CV 4/5; 57/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=100
# [CV 1/5; 10/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=200;, score=0.881 total time=  36.9s
# [CV 5/5; 57/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=100
# [CV 5/5; 11/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=500;, score=0.896 total time=  37.3s
# [CV 1/5; 58/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=200
# [CV 2/5; 34/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200;, score=0.951 total time=  38.0s
# [CV 2/5; 58/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=200
# [CV 4/5; 10/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=200;, score=0.893 total time=  37.8s
# [CV 3/5; 58/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=200
# [CV 3/5; 5/120] END criterion=gini, max_depth=6, max_features=sqrt, n_estimators=100;, score=0.890 total time=  40.2s
# [CV 4/5; 58/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=200
# [CV 3/5; 1/120] END criterion=gini, max_depth=6, max_features=auto, n_estimators=100;, score=0.890 total time=  41.0s
# [CV 5/5; 58/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=200
# [CV 1/5; 34/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200;, score=0.943 total time=  40.8s
# [CV 1/5; 22/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=200;, score=0.916 total time=  41.3s
# [CV 1/5; 59/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=500
# [CV 2/5; 59/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=500
# [CV 4/5; 34/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200;, score=0.942 total time=  36.7s
# [CV 4/5; 5/120] END criterion=gini, max_depth=6, max_features=sqrt, n_estimators=100;, score=0.908 total time=  40.4s
# [CV 3/5; 59/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=500
# [CV 4/5; 59/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=500
# [CV 1/5; 45/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=100;, score=0.953 total time=  36.0s
# [CV 5/5; 59/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=500
# [CV 1/5; 1/120] END criterion=gini, max_depth=6, max_features=auto, n_estimators=100;, score=0.899 total time=  41.5s
# [CV 1/5; 60/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=1000
# [CV 1/5; 5/120] END criterion=gini, max_depth=6, max_features=sqrt, n_estimators=100;, score=0.899 total time=  43.1s
# [CV 2/5; 60/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=1000
# [CV 1/5; 57/120] END criterion=gini, max_depth=14, max_features=log2, n_estimators=100;, score=0.959 total time=  11.6s
# [CV 3/5; 60/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=1000
# [CV 2/5; 23/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=500;, score=0.931 total time=  43.9s
# [CV 4/5; 60/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=1000
# [CV 2/5; 22/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=200;, score=0.933 total time=  49.9s
# [CV 4/5; 57/120] END criterion=gini, max_depth=14, max_features=log2, n_estimators=100;, score=0.958 total time=  14.7s
# [CV 5/5; 60/120] START criterion=gini, max_depth=14, max_features=log2, n_estimators=1000
# [CV 1/5; 61/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=100
# [CV 5/5; 17/120] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=100;, score=0.938 total time=  51.2s
# [CV 2/5; 61/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=100
# [CV 3/5; 17/120] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=100;, score=0.935 total time=  53.0s
# [CV 3/5; 61/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=100
# [CV 3/5; 34/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=200;, score=0.943 total time=  48.6s
# [CV 1/5; 13/120] END criterion=gini, max_depth=8, max_features=auto, n_estimators=100;, score=0.931 total time=  51.6s
# [CV 4/5; 61/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=100
# [CV 5/5; 61/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=100
# [CV 5/5; 1/120] END criterion=gini, max_depth=6, max_features=auto, n_estimators=100;, score=0.902 total time=  54.0s
# [CV 1/5; 62/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=200
# [CV 3/5; 57/120] END criterion=gini, max_depth=14, max_features=log2, n_estimators=100;, score=0.959 total time=  19.5s
# [CV 2/5; 62/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=200
# [CV 2/5; 5/120] END criterion=gini, max_depth=6, max_features=sqrt, n_estimators=100;, score=0.907 total time=  53.5s
# [CV 3/5; 62/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=200
# [CV 4/5; 46/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=200;, score=0.953 total time=  48.9s
# [CV 4/5; 62/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=200
# [CV 4/5; 23/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=500;, score=0.923 total time=  57.8s
# [CV 5/5; 62/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=200
# [CV 2/5; 47/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=500;, score=0.962 total time=  51.9s
# [CV 1/5; 63/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=500
# [CV 1/5; 58/120] END criterion=gini, max_depth=14, max_features=log2, n_estimators=200;, score=0.960 total time=  22.8s
# [CV 2/5; 63/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=500
# [CV 4/5; 29/120] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.953 total time=  58.8s
# [CV 3/5; 63/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=500
# [CV 5/5; 46/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=200;, score=0.953 total time=  51.6s
# [CV 4/5; 63/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=500
# [CV 2/5; 46/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=200;, score=0.960 total time=  54.7s
# [CV 5/5; 63/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=500
# [CV 4/5; 58/120] END criterion=gini, max_depth=14, max_features=log2, n_estimators=200;, score=0.958 total time=  23.1s
# [CV 1/5; 64/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=1000
# [CV 5/5; 5/120] END criterion=gini, max_depth=6, max_features=sqrt, n_estimators=100;, score=0.902 total time= 1.1min
# [CV 2/5; 64/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=1000
# [CV 2/5; 57/120] END criterion=gini, max_depth=14, max_features=log2, n_estimators=100;, score=0.965 total time=  30.2s
# [CV 5/5; 58/120] END criterion=gini, max_depth=14, max_features=log2, n_estimators=200;, score=0.962 total time=  23.2s
# [CV 3/5; 64/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=1000
# [CV 4/5; 64/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=1000
# [CV 2/5; 11/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=500;, score=0.903 total time= 1.1min
# [CV 5/5; 64/120] START criterion=entropy, max_depth=6, max_features=auto, n_estimators=1000
# [CV 2/5; 17/120] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=100;, score=0.942 total time= 1.1min
# [CV 1/5; 65/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=100
# [CV 5/5; 23/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=500;, score=0.926 total time= 1.1min
# [CV 2/5; 65/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=100
# [CV 4/5; 12/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=1000;, score=0.896 total time= 1.1min
# [CV 5/5; 13/120] END criterion=gini, max_depth=8, max_features=auto, n_estimators=100;, score=0.938 total time= 1.1min
# [CV 3/5; 65/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=100
# [CV 4/5; 65/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=100
# [CV 3/5; 35/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=500;, score=0.941 total time= 1.1min
# [CV 5/5; 65/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=100
# [CV 4/5; 1/120] END criterion=gini, max_depth=6, max_features=auto, n_estimators=100;, score=0.908 total time= 1.1min
# [CV 1/5; 66/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=200
# [CV 5/5; 57/120] END criterion=gini, max_depth=14, max_features=log2, n_estimators=100;, score=0.960 total time=  31.2s
# [CV 2/5; 66/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=200
# [CV 5/5; 37/120] END criterion=gini, max_depth=12, max_features=auto, n_estimators=100;, score=0.959 total time= 1.1min
# [CV 3/5; 66/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=200
# [CV 1/5; 35/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=500;, score=0.943 total time= 1.1min
# [CV 4/5; 66/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=200
# [CV 2/5; 12/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=1000;, score=0.902 total time= 1.1min
# [CV 5/5; 66/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=200
# [CV 2/5; 1/120] END criterion=gini, max_depth=6, max_features=auto, n_estimators=100;, score=0.907 total time= 1.2min
# [CV 1/5; 67/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=500
# [CV 1/5; 17/120] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=100;, score=0.931 total time= 1.1min
# [CV 2/5; 67/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=500
# [CV 2/5; 35/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=500;, score=0.948 total time= 1.1min
# [CV 3/5; 67/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=500
# [CV 3/5; 25/120] END criterion=gini, max_depth=10, max_features=auto, n_estimators=100;, score=0.957 total time= 1.2min
# [CV 4/5; 67/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=500
# [CV 3/5; 46/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=200;, score=0.955 total time= 1.1min
# [CV 5/5; 67/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=500
# [CV 5/5; 49/120] END criterion=gini, max_depth=14, max_features=auto, n_estimators=100;, score=0.961 total time= 1.1min
# [CV 1/5; 68/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=1000
# [CV 3/5; 2/120] END criterion=gini, max_depth=6, max_features=auto, n_estimators=200;, score=0.894 total time= 1.3min
# [CV 2/5; 68/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=1000
# [CV 4/5; 49/120] END criterion=gini, max_depth=14, max_features=auto, n_estimators=100;, score=0.962 total time= 1.1min
# [CV 3/5; 68/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=1000
# [CV 1/5; 6/120] END criterion=gini, max_depth=6, max_features=sqrt, n_estimators=200;, score=0.903 total time= 1.3min
# [CV 4/5; 68/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=1000
# [CV 1/5; 2/120] END criterion=gini, max_depth=6, max_features=auto, n_estimators=200;, score=0.903 total time= 1.3min
# [CV 5/5; 68/120] START criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=1000
# [CV 2/5; 58/120] END criterion=gini, max_depth=14, max_features=log2, n_estimators=200;, score=0.965 total time=  39.5s
# [CV 1/5; 69/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=100
# [CV 4/5; 11/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=500;, score=0.896 total time= 1.3min
# [CV 2/5; 69/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=100
# [CV 5/5; 2/120] END criterion=gini, max_depth=6, max_features=auto, n_estimators=200;, score=0.905 total time= 1.3min
# [CV 3/5; 69/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=100
# [CV 5/5; 25/120] END criterion=gini, max_depth=10, max_features=auto, n_estimators=100;, score=0.953 total time= 1.3min
# [CV 4/5; 69/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=100
# [CV 1/5; 25/120] END criterion=gini, max_depth=10, max_features=auto, n_estimators=100;, score=0.946 total time= 1.3min
# [CV 5/5; 69/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=100
# [CV 1/5; 53/120] END criterion=gini, max_depth=14, max_features=sqrt, n_estimators=100;, score=0.960 total time= 1.1min
# [CV 1/5; 70/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=200
# [CV 2/5; 41/120] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.962 total time= 1.4min
# [CV 2/5; 70/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=200
# [CV 4/5; 17/120] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=100;, score=0.935 total time= 1.4min
# [CV 3/5; 70/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=200
# [CV 5/5; 41/120] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.959 total time= 1.4min
# [CV 4/5; 70/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=200
# [CV 2/5; 53/120] END criterion=gini, max_depth=14, max_features=sqrt, n_estimators=100;, score=0.966 total time= 1.2min
# [CV 5/5; 70/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=200
# [CV 3/5; 41/120] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.957 total time= 1.4min
# [CV 1/5; 71/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=500
# [CV 2/5; 37/120] END criterion=gini, max_depth=12, max_features=auto, n_estimators=100;, score=0.962 total time= 1.4min
# [CV 2/5; 71/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=500
# [CV 3/5; 58/120] END criterion=gini, max_depth=14, max_features=log2, n_estimators=200;, score=0.958 total time=  47.9s
# [CV 3/5; 71/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=500
# [CV 5/5; 12/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=1000;, score=0.895 total time= 1.5min
# [CV 4/5; 71/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=500
# [CV 1/5; 41/120] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=100;, score=0.958 total time= 1.4min
# [CV 5/5; 71/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=500
# [CV 1/5; 24/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=1000;, score=0.918 total time= 1.5min
# [CV 1/5; 72/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=1000
# [CV 3/5; 69/120] END criterion=entropy, max_depth=6, max_features=log2, n_estimators=100;, score=0.878 total time=  10.1s
# [CV 2/5; 72/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=1000
# [CV 4/5; 37/120] END criterion=gini, max_depth=12, max_features=auto, n_estimators=100;, score=0.961 total time= 1.4min
# [CV 3/5; 72/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=1000
# [CV 3/5; 12/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=1000;, score=0.888 total time= 1.5min
# [CV 4/5; 72/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=1000
# [CV 3/5; 47/120] END criterion=gini, max_depth=12, max_features=log2, n_estimators=500;, score=0.956 total time= 1.4min
# [CV 5/5; 72/120] START criterion=entropy, max_depth=6, max_features=log2, n_estimators=1000
# [CV 2/5; 29/120] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.958 total time= 1.5min
# [CV 1/5; 73/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=100
# [CV 5/5; 35/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=500;, score=0.945 total time= 1.5min
# [CV 2/5; 73/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=100
# [CV 3/5; 23/120] END criterion=gini, max_depth=8, max_features=log2, n_estimators=500;, score=0.918 total time= 1.5min
# [CV 3/5; 11/120] END criterion=gini, max_depth=6, max_features=log2, n_estimators=500;, score=0.887 total time= 1.5min
# [CV 3/5; 73/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=100
# [CV 4/5; 25/120] END criterion=gini, max_depth=10, max_features=auto, n_estimators=100;, score=0.953 total time= 1.5min
# [CV 4/5; 73/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=100
# [CV 5/5; 73/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=100
# [CV 2/5; 25/120] END criterion=gini, max_depth=10, max_features=auto, n_estimators=100;, score=0.958 total time= 1.5min
# [CV 1/5; 74/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=200
# [CV 1/5; 69/120] END criterion=entropy, max_depth=6, max_features=log2, n_estimators=100;, score=0.873 total time=  14.3s
# [CV 2/5; 74/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=200
# [CV 4/5; 69/120] END criterion=entropy, max_depth=6, max_features=log2, n_estimators=100;, score=0.888 total time=  12.2s
# [CV 3/5; 74/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=200
# [CV 4/5; 13/120] END criterion=gini, max_depth=8, max_features=auto, n_estimators=100;, score=0.935 total time= 1.6min
# [CV 5/5; 69/120] END criterion=entropy, max_depth=6, max_features=log2, n_estimators=100;, score=0.888 total time=  11.8s
# [CV 4/5; 74/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=200
# [CV 5/5; 74/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=200
# [CV 2/5; 69/120] END criterion=entropy, max_depth=6, max_features=log2, n_estimators=100;, score=0.895 total time=  18.9s
# [CV 1/5; 75/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=500
# [CV 2/5; 13/120] END criterion=gini, max_depth=8, max_features=auto, n_estimators=100;, score=0.942 total time= 1.6min
# [CV 2/5; 75/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=500
# [CV 3/5; 29/120] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.957 total time= 1.7min
# [CV 3/5; 75/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=500
# [CV 1/5; 29/120] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.946 total time= 1.6min
# [CV 4/5; 75/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=500
# [CV 4/5; 35/120] END criterion=gini, max_depth=10, max_features=log2, n_estimators=500;, score=0.943 total time= 1.6min
# [CV 5/5; 75/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=500
# [CV 1/5; 14/120] END criterion=gini, max_depth=8, max_features=auto, n_estimators=200;, score=0.930 total time= 1.7min
# [CV 1/5; 76/120] START criterion=entropy, max_depth=8, max_features=auto, n_estimators=1000
# ...
# [CV 4/5; 79/120] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500;, score=0.940 total time= 6.2min
# [CV 4/5; 75/120] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=500;, score=0.940 total time= 6.5min
# [CV 5/5; 4/120] END criterion=gini, max_depth=6, max_features=auto, n_estimators=1000;, score=0.907 total time= 8.2min
# [CV 5/5; 75/120] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=500;, score=0.939 total time= 6.5min
# [CV 1/5; 79/120] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500;, score=0.933 total time= 6.4min
# [CV 3/5; 79/120] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500;, score=0.931 total time= 6.4min
# [CV 5/5; 79/120] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=500;, score=0.939 total time= 6.5min
# [CV 1/5; 87/120] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=500;, score=0.958 total time= 6.4min
# [CV 3/5; 20/120] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=1000;, score=0.927 total time= 8.8min
# [CV 5/5; 16/120] END criterion=gini, max_depth=8, max_features=auto, n_estimators=1000;, score=0.936 total time= 8.9min
# [CV 5/5; 87/120] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=500;, score=0.961 total time= 6.5min
# [CV 4/5; 87/120] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=500;, score=0.958 total time= 6.6min
# [CV 3/5; 91/120] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500;, score=0.956 total time= 6.4min
# [CV 3/5; 87/120] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=500;, score=0.956 total time= 6.7min
# [CV 2/5; 87/120] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=500;, score=0.962 total time= 6.7min
# [CV 1/5; 16/120] END criterion=gini, max_depth=8, max_features=auto, n_estimators=1000;, score=0.929 total time= 9.1min
# [CV 2/5; 91/120] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500;, score=0.962 total time= 6.5min
# [CV 1/5; 91/120] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500;, score=0.958 total time= 6.6min
# [CV 4/5; 91/120] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500;, score=0.958 total time= 6.6min
# [CV 1/5; 20/120] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=1000;, score=0.929 total time= 9.1min
# [CV 5/5; 91/120] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=500;, score=0.961 total time= 6.6min
# [CV 2/5; 16/120] END criterion=gini, max_depth=8, max_features=auto, n_estimators=1000;, score=0.945 total time= 9.3min
# [CV 1/5; 99/120] END criterion=entropy, max_depth=12, max_features=auto, n_estimators=500;, score=0.966 total time= 6.2min
# [CV 4/5; 20/120] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=1000;, score=0.936 total time= 9.4min
# [CV 3/5; 16/120] END criterion=gini, max_depth=8, max_features=auto, n_estimators=1000;, score=0.927 total time= 9.4min
# [CV 5/5; 20/120] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=1000;, score=0.936 total time= 9.5min
# [CV 4/5; 99/120] END criterion=entropy, max_depth=12, max_features=auto, n_estimators=500;, score=0.969 total time= 6.3min
# [CV 2/5; 20/120] END criterion=gini, max_depth=8, max_features=sqrt, n_estimators=1000;, score=0.945 total time= 9.5min
# [CV 3/5; 99/120] END criterion=entropy, max_depth=12, max_features=auto, n_estimators=500;, score=0.966 total time= 6.4min
# [CV 4/5; 16/120] END criterion=gini, max_depth=8, max_features=auto, n_estimators=1000;, score=0.936 total time= 9.6min
# [CV 1/5; 103/120] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=500;, score=0.966 total time= 6.3min
# [CV 5/5; 99/120] END criterion=entropy, max_depth=12, max_features=auto, n_estimators=500;, score=0.968 total time= 6.5min
# [CV 5/5; 64/120] END criterion=entropy, max_depth=6, max_features=auto, n_estimators=1000;, score=0.905 total time= 8.7min
# [CV 4/5; 103/120] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=500;, score=0.969 total time= 6.4min
# [CV 2/5; 99/120] END criterion=entropy, max_depth=12, max_features=auto, n_estimators=500;, score=0.971 total time= 6.8min
# [CV 2/5; 103/120] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=500;, score=0.971 total time= 6.5min
# [CV 3/5; 103/120] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=500;, score=0.966 total time= 6.6min
# [CV 5/5; 103/120] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=500;, score=0.968 total time= 6.6min
# [CV 1/5; 32/120] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1000;, score=0.951 total time=10.0min
# [CV 3/5; 32/120] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1000;, score=0.952 total time=10.1min
# [CV 5/5; 28/120] END criterion=gini, max_depth=10, max_features=auto, n_estimators=1000;, score=0.954 total time=10.0min
# [CV 4/5; 32/120] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1000;, score=0.953 total time=10.0min
# [CV 3/5; 28/120] END criterion=gini, max_depth=10, max_features=auto, n_estimators=1000;, score=0.952 total time=10.0min
# [CV 1/5; 111/120] END criterion=entropy, max_depth=14, max_features=auto, n_estimators=500;, score=0.966 total time= 6.1min
# [CV 1/5; 64/120] END criterion=entropy, max_depth=6, max_features=auto, n_estimators=1000;, score=0.897 total time= 9.2min
# [CV 3/5; 64/120] END criterion=entropy, max_depth=6, max_features=auto, n_estimators=1000;, score=0.892 total time= 9.2min
# [CV 2/5; 64/120] END criterion=entropy, max_depth=6, max_features=auto, n_estimators=1000;, score=0.904 total time= 9.2min
# [CV 2/5; 111/120] END criterion=entropy, max_depth=14, max_features=auto, n_estimators=500;, score=0.974 total time= 6.2min
# [CV 1/5; 28/120] END criterion=gini, max_depth=10, max_features=auto, n_estimators=1000;, score=0.951 total time=10.3min
# [CV 1/5; 68/120] END criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=1000;, score=0.897 total time= 9.0min
# [CV 4/5; 64/120] END criterion=entropy, max_depth=6, max_features=auto, n_estimators=1000;, score=0.907 total time= 9.3min
# [CV 5/5; 111/120] END criterion=entropy, max_depth=14, max_features=auto, n_estimators=500;, score=0.970 total time= 6.2min
# [CV 4/5; 111/120] END criterion=entropy, max_depth=14, max_features=auto, n_estimators=500;, score=0.970 total time= 6.2min
# [CV 3/5; 111/120] END criterion=entropy, max_depth=14, max_features=auto, n_estimators=500;, score=0.969 total time= 6.2min
# [CV 5/5; 68/120] END criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=1000;, score=0.905 total time= 9.1min
# [CV 4/5; 115/120] END criterion=entropy, max_depth=14, max_features=sqrt, n_estimators=500;, score=0.970 total time= 5.8min
# [CV 5/5; 115/120] END criterion=entropy, max_depth=14, max_features=sqrt, n_estimators=500;, score=0.970 total time= 5.8min
# [CV 1/5; 115/120] END criterion=entropy, max_depth=14, max_features=sqrt, n_estimators=500;, score=0.966 total time= 5.9min
# [CV 2/5; 115/120] END criterion=entropy, max_depth=14, max_features=sqrt, n_estimators=500;, score=0.974 total time= 5.8min
# [CV 3/5; 115/120] END criterion=entropy, max_depth=14, max_features=sqrt, n_estimators=500;, score=0.969 total time= 5.9min
# [CV 4/5; 68/120] END criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=1000;, score=0.907 total time= 9.2min
# [CV 4/5; 28/120] END criterion=gini, max_depth=10, max_features=auto, n_estimators=1000;, score=0.953 total time=10.5min
# [CV 3/5; 68/120] END criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=1000;, score=0.892 total time= 9.3min
# [CV 2/5; 68/120] END criterion=entropy, max_depth=6, max_features=sqrt, n_estimators=1000;, score=0.904 total time= 9.3min
# [CV 2/5; 32/120] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1000;, score=0.960 total time=10.5min
# [CV 5/5; 32/120] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=1000;, score=0.954 total time=10.6min
# [CV 2/5; 28/120] END criterion=gini, max_depth=10, max_features=auto, n_estimators=1000;, score=0.960 total time=10.7min
# [CV 4/5; 40/120] END criterion=gini, max_depth=12, max_features=auto, n_estimators=1000;, score=0.957 total time=10.8min
# [CV 5/5; 40/120] END criterion=gini, max_depth=12, max_features=auto, n_estimators=1000;, score=0.960 total time=10.9min
# [CV 4/5; 44/120] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=1000;, score=0.957 total time=10.8min
# [CV 1/5; 44/120] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=1000;, score=0.960 total time=10.9min
# [CV 1/5; 40/120] END criterion=gini, max_depth=12, max_features=auto, n_estimators=1000;, score=0.960 total time=10.9min
# [CV 3/5; 40/120] END criterion=gini, max_depth=12, max_features=auto, n_estimators=1000;, score=0.963 total time=11.1min
# [CV 2/5; 40/120] END criterion=gini, max_depth=12, max_features=auto, n_estimators=1000;, score=0.964 total time=11.1min
# [CV 5/5; 44/120] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=1000;, score=0.960 total time=11.2min
# [CV 3/5; 44/120] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=1000;, score=0.963 total time=11.4min
# [CV 2/5; 44/120] END criterion=gini, max_depth=12, max_features=sqrt, n_estimators=1000;, score=0.964 total time=11.6min
# [CV 1/5; 52/120] END criterion=gini, max_depth=14, max_features=auto, n_estimators=1000;, score=0.963 total time=11.6min
# [CV 2/5; 56/120] END criterion=gini, max_depth=14, max_features=sqrt, n_estimators=1000;, score=0.969 total time=11.3min
# [CV 5/5; 52/120] END criterion=gini, max_depth=14, max_features=auto, n_estimators=1000;, score=0.965 total time=11.5min
# [CV 4/5; 52/120] END criterion=gini, max_depth=14, max_features=auto, n_estimators=1000;, score=0.962 total time=11.6min
# [CV 3/5; 52/120] END criterion=gini, max_depth=14, max_features=auto, n_estimators=1000;, score=0.964 total time=11.8min
# [CV 4/5; 56/120] END criterion=gini, max_depth=14, max_features=sqrt, n_estimators=1000;, score=0.962 total time=11.4min
# [CV 2/5; 76/120] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=1000;, score=0.941 total time=10.3min
# [CV 2/5; 52/120] END criterion=gini, max_depth=14, max_features=auto, n_estimators=1000;, score=0.969 total time=11.9min
# [CV 1/5; 56/120] END criterion=gini, max_depth=14, max_features=sqrt, n_estimators=1000;, score=0.963 total time=11.7min
# [CV 3/5; 56/120] END criterion=gini, max_depth=14, max_features=sqrt, n_estimators=1000;, score=0.964 total time=11.6min
# [CV 1/5; 76/120] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=1000;, score=0.932 total time=10.5min
# [CV 3/5; 80/120] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=1000;, score=0.930 total time=10.3min
# [CV 1/5; 80/120] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=1000;, score=0.932 total time=10.3min
# [CV 4/5; 80/120] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=1000;, score=0.937 total time=10.3min
# [CV 2/5; 80/120] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=1000;, score=0.941 total time=10.4min
# [CV 5/5; 76/120] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=1000;, score=0.938 total time=10.5min
# [CV 4/5; 76/120] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=1000;, score=0.937 total time=10.6min
# [CV 3/5; 76/120] END criterion=entropy, max_depth=8, max_features=auto, n_estimators=1000;, score=0.930 total time=10.6min
# [CV 5/5; 80/120] END criterion=entropy, max_depth=8, max_features=sqrt, n_estimators=1000;, score=0.938 total time=10.5min
# [CV 5/5; 56/120] END criterion=gini, max_depth=14, max_features=sqrt, n_estimators=1000;, score=0.965 total time=12.0min
# [CV 2/5; 88/120] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=1000;, score=0.964 total time=10.9min
# [CV 1/5; 88/120] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=1000;, score=0.955 total time=11.0min
# [CV 5/5; 88/120] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=1000;, score=0.960 total time=10.9min
# [CV 3/5; 88/120] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=1000;, score=0.956 total time=11.1min
# [CV 5/5; 92/120] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=1000;, score=0.960 total time=11.0min
# [CV 4/5; 92/120] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=1000;, score=0.959 total time=11.0min
# [CV 3/5; 92/120] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=1000;, score=0.956 total time=11.1min
# [CV 4/5; 88/120] END criterion=entropy, max_depth=10, max_features=auto, n_estimators=1000;, score=0.959 total time=11.3min
# [CV 2/5; 92/120] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=1000;, score=0.964 total time=11.2min
# [CV 1/5; 92/120] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=1000;, score=0.955 total time=11.2min
# [CV 1/5; 100/120] END criterion=entropy, max_depth=12, max_features=auto, n_estimators=1000;, score=0.964 total time=11.1min
# [CV 1/5; 104/120] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=1000;, score=0.964 total time=10.9min
# [CV 4/5; 100/120] END criterion=entropy, max_depth=12, max_features=auto, n_estimators=1000;, score=0.967 total time=11.1min
# [CV 2/5; 100/120] END criterion=entropy, max_depth=12, max_features=auto, n_estimators=1000;, score=0.973 total time=11.1min
# [CV 5/5; 104/120] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=1000;, score=0.970 total time=10.9min
# [CV 3/5; 100/120] END criterion=entropy, max_depth=12, max_features=auto, n_estimators=1000;, score=0.966 total time=11.1min
# [CV 2/5; 104/120] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=1000;, score=0.973 total time=11.0min
# [CV 3/5; 104/120] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=1000;, score=0.966 total time=11.1min
# [CV 4/5; 104/120] END criterion=entropy, max_depth=12, max_features=sqrt, n_estimators=1000;, score=0.967 total time=11.1min
# [CV 5/5; 100/120] END criterion=entropy, max_depth=12, max_features=auto, n_estimators=1000;, score=0.970 total time=11.5min
# [CV 4/5; 112/120] END criterion=entropy, max_depth=14, max_features=auto, n_estimators=1000;, score=0.970 total time=10.6min
# [CV 1/5; 112/120] END criterion=entropy, max_depth=14, max_features=auto, n_estimators=1000;, score=0.966 total time=10.8min
# [CV 3/5; 112/120] END criterion=entropy, max_depth=14, max_features=auto, n_estimators=1000;, score=0.968 total time=10.7min
# [CV 2/5; 112/120] END criterion=entropy, max_depth=14, max_features=auto, n_estimators=1000;, score=0.974 total time=10.9min
# [CV 5/5; 112/120] END criterion=entropy, max_depth=14, max_features=auto, n_estimators=1000;, score=0.971 total time=10.7min
# [CV 3/5; 116/120] END criterion=entropy, max_depth=14, max_features=sqrt, n_estimators=1000;, score=0.968 total time=10.4min
# [CV 2/5; 116/120] END criterion=entropy, max_depth=14, max_features=sqrt, n_estimators=1000;, score=0.974 total time=10.5min
# [CV 4/5; 116/120] END criterion=entropy, max_depth=14, max_features=sqrt, n_estimators=1000;, score=0.970 total time=10.5min
# [CV 5/5; 116/120] END criterion=entropy, max_depth=14, max_features=sqrt, n_estimators=1000;, score=0.971 total time=10.5min
# [CV 1/5; 116/120] END criterion=entropy, max_depth=14, max_features=sqrt, n_estimators=1000;, score=0.966 total time=10.7min
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=1706),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [6, 8, 10, 12, 14],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 200, 500, 1000]},
#              verbose=100)

# %%
pickle.dump(CV_model, open('models/RandomForest_GridSearch.pkl', 'wb'))

# %%
CV_model.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 14,
#  'max_features': 'auto',
#  'n_estimators': 500}

# %%
best_model = RandomForestClassifier(criterion="entropy", max_depth=14, max_features="auto", n_estimators=500, verbose=5, n_jobs=-1, random_state=SEED)
best_model.fit(x_train_balanced, y_train_balanced)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 256 concurrent workers.
# building tree 1 of 500
# building tree 2 of 500
# building tree 3 of 500
# building tree 4 of 500
# building tree 5 of 500
# building tree 6 of 500
# building tree 7 of 500
# building tree 8 of 500
# building tree 9 of 500
# building tree 10 of 500
# building tree 11 of 500
# building tree 12 of 500
# building tree 13 of 500
# building tree 14 of 500
# building tree 15 of 500
# building tree 16 of 500
# building tree 17 of 500
# building tree 18 of 500
# building tree 19 of 500
# building tree 20 of 500
# building tree 21 of 500
# building tree 22 of 500
# building tree 23 of 500
# building tree 24 of 500
# building tree 25 of 500
# building tree 26 of 500
# building tree 27 of 500
# building tree 28 of 500
# building tree 29 of 500
# building tree 30 of 500
# building tree 31 of 500
# building tree 32 of 500
# building tree 33 of 500
# building tree 34 of 500
# building tree 35 of 500
# building tree 36 of 500
# building tree 37 of 500
# building tree 38 of 500
# building tree 39 of 500
# building tree 40 of 500
# building tree 41 of 500
# building tree 42 of 500building tree 43 of 500
#
# building tree 44 of 500
# building tree 45 of 500
# building tree 46 of 500
# building tree 47 of 500
# building tree 48 of 500
# building tree 49 of 500
# building tree 50 of 500building tree 51 of 500
# building tree 52 of 500
#
# building tree 53 of 500
# building tree 54 of 500building tree 55 of 500
#
# building tree 56 of 500
# building tree 57 of 500
# building tree 58 of 500
# building tree 59 of 500
# building tree 60 of 500
# building tree 61 of 500
# building tree 62 of 500
# building tree 63 of 500
# building tree 64 of 500
# building tree 65 of 500building tree 66 of 500
# building tree 67 of 500
# building tree 68 of 500
# building tree 69 of 500
#
# building tree 70 of 500
# building tree 71 of 500
# building tree 72 of 500
# building tree 73 of 500building tree 74 of 500
#
# building tree 75 of 500
# building tree 76 of 500
# building tree 77 of 500building tree 78 of 500
#
# building tree 79 of 500
# building tree 80 of 500
# building tree 81 of 500
# building tree 82 of 500
# building tree 83 of 500
# building tree 84 of 500
# building tree 85 of 500building tree 86 of 500
#
# building tree 87 of 500
# building tree 88 of 500
# building tree 89 of 500
# building tree 90 of 500
# building tree 91 of 500
# building tree 92 of 500
# building tree 93 of 500
# building tree 94 of 500
# building tree 95 of 500
# building tree 96 of 500
# building tree 97 of 500
# building tree 98 of 500building tree 99 of 500
# building tree 100 of 500
# building tree 101 of 500
#
# building tree 102 of 500
# building tree 103 of 500building tree 104 of 500
# building tree 105 of 500
# building tree 106 of 500
#
# building tree 107 of 500
# building tree 108 of 500building tree 109 of 500
#
# building tree 110 of 500
# building tree 111 of 500
# building tree 112 of 500
# building tree 113 of 500
# building tree 114 of 500
# building tree 115 of 500
# building tree 116 of 500
# building tree 117 of 500
# building tree 118 of 500
# building tree 119 of 500
# building tree 120 of 500
# building tree 121 of 500
# building tree 122 of 500
# building tree 123 of 500
# building tree 124 of 500
# building tree 125 of 500
# building tree 126 of 500
# building tree 127 of 500
# building tree 128 of 500
# building tree 129 of 500
# building tree 130 of 500
# building tree 131 of 500
# building tree 132 of 500
# building tree 133 of 500
# building tree 134 of 500
# building tree 135 of 500
# building tree 136 of 500
# building tree 137 of 500
# building tree 138 of 500building tree 139 of 500
#
# building tree 140 of 500building tree 141 of 500building tree 142 of 500
#
#
# building tree 143 of 500
# building tree 144 of 500
# building tree 145 of 500building tree 146 of 500
# building tree 147 of 500
# building tree 148 of 500
#
# building tree 149 of 500
# building tree 150 of 500
# building tree 151 of 500building tree 152 of 500
# building tree 153 of 500
#
# building tree 154 of 500
# building tree 155 of 500
# building tree 156 of 500building tree 157 of 500
#
# building tree 158 of 500building tree 159 of 500
# building tree 160 of 500
# building tree 161 of 500
# building tree 162 of 500
# building tree 163 of 500
# building tree 164 of 500
#
# building tree 165 of 500building tree 166 of 500
#
# building tree 167 of 500building tree 168 of 500
# building tree 169 of 500
#
# building tree 170 of 500
# building tree 171 of 500
# building tree 172 of 500
# building tree 173 of 500
# building tree 174 of 500
# building tree 175 of 500
# building tree 176 of 500
# building tree 177 of 500
# building tree 178 of 500
# building tree 179 of 500
# building tree 180 of 500
# building tree 181 of 500
# building tree 182 of 500
# building tree 183 of 500
# building tree 184 of 500building tree 185 of 500
# building tree 186 of 500
# building tree 187 of 500
#
# building tree 188 of 500
# building tree 189 of 500
# building tree 190 of 500
# building tree 191 of 500
# building tree 192 of 500building tree 193 of 500building tree 194 of 500
# building tree 195 of 500
# building tree 196 of 500
# building tree 197 of 500building tree 198 of 500building tree 199 of 500building tree 200 of 500
#
# building tree 201 of 500
#
# building tree 202 of 500building tree 203 of 500building tree 204 of 500
# building tree 205 of 500
#
# building tree 206 of 500
# building tree 207 of 500
#
# building tree 208 of 500
# building tree 209 of 500building tree 210 of 500building tree 211 of 500
# building tree 212 of 500
#
# building tree 213 of 500
#
# building tree 214 of 500
#
# building tree 215 of 500building tree 216 of 500
# building tree 217 of 500
# building tree 218 of 500
#
# building tree 219 of 500
#
# building tree 220 of 500
# building tree 221 of 500
# building tree 222 of 500building tree 223 of 500
# building tree 224 of 500
#
# building tree 225 of 500building tree 226 of 500building tree 227 of 500building tree 228 of 500
#
#
# building tree 229 of 500
#
# building tree 230 of 500building tree 231 of 500
# building tree 232 of 500
#
# building tree 233 of 500building tree 234 of 500building tree 235 of 500
#
# building tree 236 of 500
# building tree 237 of 500
# building tree 238 of 500
# building tree 239 of 500building tree 240 of 500building tree 241 of 500
# building tree 242 of 500
#
#
#
# building tree 243 of 500
# building tree 244 of 500
# building tree 245 of 500building tree 246 of 500
#
# building tree 247 of 500
# building tree 248 of 500building tree 249 of 500
#
#
# building tree 250 of 500
# building tree 251 of 500building tree 252 of 500building tree 253 of 500
# building tree 254 of 500building tree 255 of 500building tree 256 of 500
# building tree 257 of 500
#
#
#
# building tree 258 of 500building tree 259 of 500building tree 260 of 500
#
# building tree 261 of 500
# building tree 262 of 500
# building tree 263 of 500
# building tree 264 of 500
# building tree 265 of 500
# building tree 266 of 500
# building tree 267 of 500building tree 268 of 500
# building tree 269 of 500building tree 270 of 500
#
#
# building tree 271 of 500
#
# building tree 272 of 500
# building tree 273 of 500
# building tree 274 of 500building tree 275 of 500
# building tree 276 of 500
#
# building tree 277 of 500
# building tree 278 of 500building tree 279 of 500building tree 280 of 500
# building tree 281 of 500
# building tree 282 of 500
#
# building tree 283 of 500building tree 284 of 500building tree 285 of 500building tree 286 of 500building tree 287 of 500
# building tree 288 of 500
#
#
#
# building tree 289 of 500
#
# building tree 290 of 500
#
#
# building tree 291 of 500
# building tree 292 of 500
# building tree 293 of 500building tree 294 of 500
# building tree 295 of 500
#
# building tree 296 of 500
# building tree 297 of 500building tree 298 of 500
# building tree 299 of 500
#
# building tree 300 of 500building tree 301 of 500building tree 302 of 500building tree 303 of 500building tree 304 of 500
#
#
#
# building tree 305 of 500building tree 306 of 500
# building tree 307 of 500
#
# building tree 308 of 500
# building tree 309 of 500building tree 310 of 500building tree 311 of 500
# building tree 312 of 500
# building tree 313 of 500
# building tree 314 of 500
# building tree 315 of 500building tree 316 of 500building tree 317 of 500
# building tree 318 of 500building tree 319 of 500
# building tree 320 of 500
#
#
#
# building tree 321 of 500
# building tree 322 of 500
#
# building tree 323 of 500
# building tree 324 of 500
# building tree 325 of 500building tree 326 of 500building tree 327 of 500
# [Parallel(n_jobs=-1)]: Done  90 out of 500 | elapsed:    3.3s remaining:   15.1s
# building tree 328 of 500
# building tree 329 of 500
#
#
#
# building tree 330 of 500
#
# building tree 331 of 500building tree 332 of 500
# building tree 333 of 500building tree 334 of 500
#
# building tree 335 of 500
# building tree 336 of 500
#
# building tree 337 of 500
# building tree 338 of 500
#
# building tree 339 of 500building tree 340 of 500building tree 341 of 500
#
#
# building tree 342 of 500building tree 343 of 500
# building tree 344 of 500
# building tree 345 of 500
# building tree 346 of 500
# building tree 347 of 500
#
# building tree 348 of 500building tree 349 of 500
# building tree 350 of 500
# building tree 351 of 500
# building tree 352 of 500
#
# building tree 353 of 500
# building tree 354 of 500
# building tree 355 of 500building tree 356 of 500
# building tree 357 of 500
# building tree 358 of 500building tree 359 of 500
# building tree 360 of 500building tree 361 of 500building tree 362 of 500
#
#
#
# building tree 363 of 500
#
# building tree 364 of 500building tree 365 of 500building tree 366 of 500
#
#
# building tree 367 of 500building tree 368 of 500
# building tree 369 of 500
# building tree 370 of 500building tree 371 of 500
#
# building tree 372 of 500
# building tree 373 of 500
#
# building tree 374 of 500
# building tree 375 of 500building tree 376 of 500
# building tree 377 of 500
#
# building tree 378 of 500building tree 379 of 500
# building tree 380 of 500
# building tree 381 of 500
# building tree 382 of 500
# building tree 383 of 500building tree 384 of 500
#
#
# building tree 385 of 500building tree 386 of 500
# building tree 387 of 500
# building tree 388 of 500
# building tree 389 of 500building tree 390 of 500building tree 391 of 500
#
# building tree 392 of 500
# building tree 393 of 500
# building tree 394 of 500building tree 395 of 500
# building tree 396 of 500
#
#
# building tree 397 of 500building tree 398 of 500building tree 399 of 500building tree 400 of 500
#
#
#
# building tree 401 of 500
# building tree 402 of 500building tree 403 of 500building tree 404 of 500
# building tree 405 of 500building tree 406 of 500
#
#
# building tree 407 of 500
# building tree 408 of 500
#
# building tree 409 of 500building tree 410 of 500
# building tree 411 of 500building tree 412 of 500
#
#
# building tree 414 of 500
# building tree 415 of 500building tree 413 of 500
# building tree 416 of 500
# building tree 417 of 500building tree 418 of 500
# building tree 419 of 500building tree 420 of 500
#
# building tree 421 of 500building tree 422 of 500
# building tree 423 of 500
#
# building tree 424 of 500building tree 425 of 500building tree 426 of 500
#
#
# building tree 427 of 500
#
# building tree 428 of 500building tree 429 of 500
#
# building tree 430 of 500
# building tree 431 of 500
# building tree 432 of 500
#
# building tree 433 of 500
#
# building tree 434 of 500
# building tree 435 of 500
# building tree 436 of 500
# building tree 437 of 500building tree 438 of 500
# building tree 439 of 500building tree 440 of 500
# building tree 441 of 500
#
# building tree 442 of 500
# building tree 443 of 500
# [Parallel(n_jobs=-1)]: Done 191 out of 500 | elapsed:    6.0s remaining:    9.7s
# building tree 444 of 500building tree 445 of 500building tree 446 of 500
#
# building tree 447 of 500
#
# building tree 448 of 500
# building tree 449 of 500building tree 450 of 500
# building tree 451 of 500building tree 452 of 500
# building tree 453 of 500building tree 454 of 500
#
# building tree 455 of 500
# building tree 456 of 500
# building tree 457 of 500building tree 458 of 500
#
# building tree 460 of 500
# building tree 462 of 500
# building tree 459 of 500building tree 463 of 500
# building tree 464 of 500
# building tree 465 of 500
#
#
# building tree 466 of 500
# building tree 467 of 500
# building tree 461 of 500building tree 468 of 500building tree 469 of 500
#
#
# building tree 470 of 500building tree 471 of 500building tree 472 of 500
#
# building tree 473 of 500
# building tree 474 of 500building tree 475 of 500
# building tree 476 of 500
#
#
#
# building tree 477 of 500
# building tree 478 of 500building tree 479 of 500
# building tree 480 of 500
# building tree 481 of 500
# building tree 482 of 500building tree 483 of 500building tree 484 of 500
#
# building tree 485 of 500building tree 486 of 500
# building tree 487 of 500
#
# building tree 488 of 500
# building tree 489 of 500
#
# building tree 490 of 500
#
# building tree 491 of 500
# building tree 492 of 500
# building tree 493 of 500building tree 494 of 500building tree 495 of 500building tree 496 of 500
#
# building tree 497 of 500
#
#
# building tree 498 of 500building tree 500 of 500
# building tree 499 of 500
# [Parallel(n_jobs=-1)]: Done 292 out of 500 | elapsed:    8.4s remaining:    6.0s
# [Parallel(n_jobs=-1)]: Done 393 out of 500 | elapsed:   10.4s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 494 out of 500 | elapsed:   11.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   11.4s finished
# RandomForestClassifier(criterion='entropy', max_depth=14, n_estimators=500,
#                        n_jobs=-1, random_state=1706, verbose=5)

# %%
y_pred = best_model.predict(x_test)
# Out:
# [Parallel(n_jobs=256)]: Using backend ThreadingBackend with 256 concurrent workers.
# [Parallel(n_jobs=256)]: Done  90 out of 500 | elapsed:    0.4s remaining:    1.7s
# [Parallel(n_jobs=256)]: Done 191 out of 500 | elapsed:    0.5s remaining:    0.9s
# [Parallel(n_jobs=256)]: Done 292 out of 500 | elapsed:    0.6s remaining:    0.4s
# [Parallel(n_jobs=256)]: Done 393 out of 500 | elapsed:    0.6s remaining:    0.2s
# [Parallel(n_jobs=256)]: Done 494 out of 500 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=256)]: Done 500 out of 500 | elapsed:    0.6s finished

# %%
print(f"Confusion Matrix \n {confusion_matrix(y_test, y_pred)}", end=('\n'*2))
print(f"ROC CURVE {roc_curve(y_test, y_pred)}", end=('\n'*2))
print(f"ROC AUC SCORE: {roc_auc_score(y_test, y_pred)}", end=('\n'*2))
print(classification_report(y_test,y_pred), )
# Out:
# Confusion Matrix
#  [[1471   69]
#  [ 138 7977]]
#
# ROC CURVE (array([0.        , 0.04480519, 1.        ]), array([0.        , 0.98299445, 1.        ]), array([2., 1., 0.]))
#
# ROC AUC SCORE: 0.9690946299541494
#
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.96      0.93      1540
#          1.0       0.99      0.98      0.99      8115
#
#     accuracy                           0.98      9655
#    macro avg       0.95      0.97      0.96      9655
# weighted avg       0.98      0.98      0.98      9655

# %%
y_test[y_test ==0].shape
# Out:
# (1540,)

# %%
x_test.shape
# Out:
# (9655, 5595)

# %%
x_train_balanced.shape
# Out:
# (12364, 5595)
